# %%
from sklearn.ensemble import GradientBoostingRegressor
#import streamlit as st
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import OneHotEncoder


model = pickle.load(open( "fit_model.p", "rb" ))
#models = pickle.load(open( "model.p", "rb" ))
#pipeline = pickle.load(open( "pipeline.p", "rb" ))
def transform(data):    
        enc = OneHotEncoder(handle_unknown='ignore')
       # enc_df = pd.DataFrame(enc.fit_transform(data[['sex','children','smoker','region']]).toarray())
        data = pd.get_dummies(data, columns=['sex','children','smoker','region'])
        return data

def predict(model, input_df):
    transform_data = transform(input_df)
    predictions_df = model.predict(transform_data)
   # predictions = predictions_df['Label'][0]
    return predictions_df

# %%
data = pd.read_csv('insurance.csv')

# %%
d = data[:100]

# %%
d=d.drop(columns=['charges'],axis=1)

# %%
d
# Out:
#     age     sex     bmi  children smoker     region
# 0    19  female  27.900         0    yes  southwest
# 1    18    male  33.770         1     no  southeast
# 2    28    male  33.000         3     no  southeast
# 3    33    male  22.705         0     no  northwest
# 4    32    male  28.880         0     no  northwest
# 5    31  female  25.740         0     no  southeast
# 6    46  female  33.440         1     no  southeast
# 7    37  female  27.740         3     no  northwest
# 8    37    male  29.830         2     no  northeast
# 9    60  female  25.840         0     no  northwest
# 10   25    male  26.220         0     no  northeast
# 11   62  female  26.290         0    yes  southeast
# 12   23    male  34.400         0     no  southwest
# 13   56  female  39.820         0     no  southeast
# 14   27    male  42.130         0    yes  southeast
# 15   19    male  24.600         1     no  southwest
# 16   52  female  30.780         1     no  northeast
# ...

# %%
predict(model,d)
# Out:
# array([16520.31268371,  3036.90109381,  5138.96392737, 14163.87443101,
#         4029.44191982,  3977.15635167,  7843.59314605,  6805.29945061,
#        11577.83091403, 19017.09819039,  2236.87349882, 28775.15274763,
#         1915.65169805, 11706.37895716, 38540.42582137,  2499.20459692,
#        12162.79708547,  1853.21232545, 10336.77020644, 36511.6052462 ,
#        14376.65888095,  3909.5064156 ,  1699.60761723, 38445.92095032,
#         6516.26810369, 14531.78299623, 13689.85822119, 12533.70892302,
#         3241.43088564, 40789.17987763, 36138.12847284,  2652.09139943,
#         3519.2592516 , 14260.01251561, 47231.08530093,  1252.54072552,
#        16647.85140914,  1755.07359951, 42982.23733482, 48241.63497111,
#         5602.72864916,  4201.71329891,  6431.43794552,  6178.79971016,
#         7754.27275672, 13986.18378309,  4515.33154386,  3408.07732338,
#        14419.4511928 , 37901.91886731,  2717.49972651,  5857.38317907,
# ...

# %%
model.predict(transform(d))
# Out:
# array([16520.31268371,  3036.90109381,  5138.96392737, 14163.87443101,
#         4029.44191982,  3977.15635167,  7843.59314605,  6805.29945061,
#        11577.83091403, 19017.09819039,  2236.87349882, 28775.15274763,
#         1915.65169805, 11706.37895716, 38540.42582137,  2499.20459692,
#        12162.79708547,  1853.21232545, 10336.77020644, 36511.6052462 ,
#        14376.65888095,  3909.5064156 ,  1699.60761723, 38445.92095032,
#         6516.26810369, 14531.78299623, 13689.85822119, 12533.70892302,
#         3241.43088564, 40789.17987763, 36138.12847284,  2652.09139943,
#         3519.2592516 , 14260.01251561, 47231.08530093,  1252.54072552,
#        16647.85140914,  1755.07359951, 42982.23733482, 48241.63497111,
#         5602.72864916,  4201.71329891,  6431.43794552,  6178.79971016,
#         7754.27275672, 13986.18378309,  4515.33154386,  3408.07732338,
#        14419.4511928 , 37901.91886731,  2717.49972651,  5857.38317907,
# ...

# %%
transform(d).shape
# Out:
# (100, 16)

# %%
te = pd.read_csv('te.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
pd.read_csv('insurance copy 2.csv')
# Out:
#      age;sex;bmi;children;smoker
# 0           19;female;27.9;0;yes
# 1             18;male;33.77;1;no
# 2                28;male;33;3;no
# 3            33;male;22.705;0;no
# 4             32;male;28.88;0;no
# ...                          ...
# 1333          50;male;30.97;3;no
# 1334        18;female;31.92;0;no
# 1335        18;female;36.85;0;no
# 1336         21;female;25.8;0;no
# 1337       61;female;29.07;0;yes
#
# [1338 rows x 1 columns]

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
